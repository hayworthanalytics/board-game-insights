# %% [markdown]
# # Board Game Insights: Data Exploration & Feature Engineering
# Welcome! This notebook explores a dataset from BoardGameGeek (BGG), featuring all ranked games in their database as of February 2021.
#
# My goal is to turn messy, real-world data into actionable insights. It sounds just like what I do at work, but I digress! For some reason, using board game data is more fun. This exploratory analysis will lay the groundwork for visualizations and future machine learning models.<br>
#
# **Project Roadmap:**
# 1. **Data Ingestion:** Explore the data in its raw form, assess what can be cleaned up for better handling, and establish parsing rules
# 2. **Data Cleaning:** Cast data types, handle nulls, and standardize text features
# 3. **Exploratory Data Analysis (EDA):** Uncover insights and have fun with visualization libraries!
# 4. **Feature Engineering:** Prepare the dataset for BI tools and/or predictive modeling
#
# Thanks for joining me in this valiant effort. Let's see what we can cook up!

# %% [markdown]
# ## Setup and Initialization

# %%
# import packages that give me workable data
import pandas as pd
import numpy as np

# import packages that give me pretty data
pd.set_option('display.max_columns', None)     # Remove column limit in displays
from IPython.display import display, Markdown  # Allows me to use Markdown logic as code in my output

# Setup Constants
FILE_PATH = "bgg_dataset.csv" 

# Establish path
import pathlib
PATH = pathlib.Path(r"C:\Users\kyrst\OneDrive\Documents\DataAnalyticsPortfolio\bgg")

# Import CSV
df = pd.read_csv(PATH / FILE_PATH, sep=";") # sep is needed since this dataset separates columns with ;

# view sample
print(f"# Columns: {len(df.columns):,}")
print(f"# Rows: {len(df):,}")
print(f"# Unique Board Games: {df['ID'].nunique():,}")
df.head()
# Out:
# # Columns: 14
# # Rows: 20,343
# # Unique Board Games: 20,327
#          ID                               Name  Year Published  Min Players  \
# 0  174430.0                         Gloomhaven          2017.0            1
# 1  161936.0          Pandemic Legacy: Season 1          2015.0            2
# 2  224517.0                  Brass: Birmingham          2018.0            2
# 3  167791.0                  Terraforming Mars          2016.0            1
# 4  233078.0  Twilight Imperium: Fourth Edition          2017.0            3
#
#    Max Players  Play Time  Min Age  Users Rated Rating Average  BGG Rank  \
# 0            4        120       14        42055           8,79         1
# 1            4         60       13        41643           8,61         2
# 2            4        120       14        19217           8,66         3
# 3            5        120       12        64864           8,43         4
# 4            6        480       14        13468           8,70         5
#
#   Complexity Average  Owned Users  \
# 0               3,86      68323.0
# 1               2,84      65294.0
# 2               3,91      28785.0
# 3               3,24      87099.0
# 4               4,22      16831.0
#
#                                            Mechanics  \
# 0  Action Queue, Action Retrieval, Campaign / Bat...
# 1  Action Points, Cooperative Game, Hand Manageme...
# 2  Hand Management, Income, Loans, Market, Networ...
# 3  Card Drafting, Drafting, End Game Bonuses, Han...
# 4  Action Drafting, Area Majority / Influence, Ar...
#
#                           Domains
# 0  Strategy Games, Thematic Games
# 1  Strategy Games, Thematic Games
# 2                  Strategy Games
# 3                  Strategy Games
# 4  Strategy Games, Thematic Games

# %% [markdown]
# **For fun, let's view another sample. This time, make it random.**
# - df.head() shows the first 5 rows by default, which are usually cleaner due to getting more attention
# - Note that this random sample has NaN values

# %%
display(df.sample(5))
# Out:
#              ID                              Name  Year Published  \
# 18607   66251.0                         Galapagos          2010.0
# 8759    25687.0                           Fragile          2006.0
# 5057   236709.0  The Tea Dragon Society Card Game          2018.0
# 19508    8636.0                  The Grape Escape          1992.0
# 5471   112991.0                    Munchkin Conan          2012.0
#
#        Min Players  Max Players  Play Time  Min Age  Users Rated  \
# 18607            2            5         60       12          130
# 8759             1            4         35       10          141
# 5057             2            4         60       10          591
# 19508            2            4         20        5          181
# 5471             3            6         90       10          380
#
#       Rating Average  BGG Rank Complexity Average  Owned Users  \
# 18607           5,30     18609               2,33        255.0
# 8759            6,36      8761               2,77        200.0
# 5057            6,31      5059               1,44       1522.0
# 19508           5,27     19510               1,21        350.0
# 5471            6,45      5473               1,64       1373.0
#
#                                                Mechanics           Domains
# 18607   Auction/Bidding, Hand Management, Set Collection               NaN
# 8759                                       Action Points    Abstract Games
# 5057   Card Drafting, Deck Bag and Pool Building, Pus...               NaN
# 19508                               Roll / Spin and Move  Children's Games
# 5471   Dice Rolling, Hand Management, Take That, Vari...               NaN

# %% [markdown]
# ## Data Cleaning
# - First, let's get a column summary using using df.info()
# - Next, we'll see what quick fixes are possible
# - Finally, the super cool exciting stuff: null and duplicate handling!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20343 entries, 0 to 20342
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  20327 non-null  float64
#  1   Name                20343 non-null  object
#  2   Year Published      20342 non-null  float64
#  3   Min Players         20343 non-null  int64
#  4   Max Players         20343 non-null  int64
#  5   Play Time           20343 non-null  int64
#  6   Min Age             20343 non-null  int64
#  7   Users Rated         20343 non-null  int64
#  8   Rating Average      20343 non-null  object
#  9   BGG Rank            20343 non-null  int64
#  10  Complexity Average  20343 non-null  object
#  11  Owned Users         20320 non-null  float64
#  12  Mechanics           18745 non-null  object
#  13  Domains             10184 non-null  object
# dtypes: float64(3), int64(6), object(5)
# memory usage: 2.2+ MB

# %% [markdown]
# **Conclusions**
# - `ID`, `Year Published` and `Owned Users` don't need to be floats. Later, we'll turn ID into a string since it's not meant to be used for math and is simply a randomly generated number. The other two fields should be integers
# - `Rating Average` and `Complexity Average` use commas instead of decimal points, which makes pandas interpret them as objects
# - `Name`, `Mechanics`, and `Domains` are objects that should be strings (due to having nulls)
# - The combination of commas replacing decimal points and a semicolon column separator tells us that this is likely a European dataset. That's useful for data cleaning and provides supporting evidence for who to pressure to play board games with me in my personal life.
#
# We can fix some of this by importing the dataset again and establishing some rules up front!

# %%
# Let's re-read the dataset and establish more rules up front

# Establish custom data types for the problem children using a dictionary:
# Note: Using capital letters (ex: "Int64" vs. "int64") uses the nullable version
# This is useful because standard integers fail if they encounter a null value (nulls prefer floats)
custom_dtypes = {
    'ID': 'string',
    'Year Published': 'Int64',
    'Owned Users': 'Int64'
}

# Ingest data
df = pd.read_csv(
    PATH / FILE_PATH,     # Remember when we established these constants up front?
    sep=";",              # Tells pandas to look for semicolons as the dataset separator
    decimal=",",          # Fixes the '8,5' vs '8.5' issue automatically
    engine="pyarrow",     # Uses the fast arrow engine for reading
    dtype=custom_dtypes,  # Uses the custom dictionary above 
    
    # Let numpy determine the column type for remaining columns.
    # "nullable" tells numpy to keep a column's native type.
    # Otherwise, a single pd.NA would lead the whole column to become a float.
    dtype_backend="numpy_nullable"                                                                          
)

df.head()
# Out:
#        ID                               Name  Year Published  Min Players  \
# 0  174430                         Gloomhaven            2017            1
# 1  161936          Pandemic Legacy: Season 1            2015            2
# 2  224517                  Brass: Birmingham            2018            2
# 3  167791                  Terraforming Mars            2016            1
# 4  233078  Twilight Imperium: Fourth Edition            2017            3
#
#    Max Players  Play Time  Min Age  Users Rated  Rating Average  BGG Rank  \
# 0            4        120       14        42055            8.79         1
# 1            4         60       13        41643            8.61         2
# 2            4        120       14        19217            8.66         3
# 3            5        120       12        64864            8.43         4
# 4            6        480       14        13468             8.7         5
#
#    Complexity Average  Owned Users  \
# 0                3.86        68323
# 1                2.84        65294
# 2                3.91        28785
# 3                3.24        87099
# 4                4.22        16831
#
#                                            Mechanics  \
# 0  Action Queue, Action Retrieval, Campaign / Bat...
# 1  Action Points, Cooperative Game, Hand Manageme...
# 2  Hand Management, Income, Loans, Market, Networ...
# 3  Card Drafting, Drafting, End Game Bonuses, Han...
# 4  Action Drafting, Area Majority / Influence, Ar...
#
#                           Domains
# 0  Strategy Games, Thematic Games
# 1  Strategy Games, Thematic Games
# 2                  Strategy Games
# 3                  Strategy Games
# 4  Strategy Games, Thematic Games

# %% [markdown]
# **Confirm it worked:**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20343 entries, 0 to 20342
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  20327 non-null  string
#  1   Name                20343 non-null  string
#  2   Year Published      20342 non-null  Int64
#  3   Min Players         20343 non-null  Int64
#  4   Max Players         20343 non-null  Int64
#  5   Play Time           20343 non-null  Int64
#  6   Min Age             20343 non-null  Int64
#  7   Users Rated         20343 non-null  Int64
#  8   Rating Average      20343 non-null  Float64
#  9   BGG Rank            20343 non-null  Int64
#  10  Complexity Average  20343 non-null  Float64
#  11  Owned Users         20320 non-null  Int64
#  12  Mechanics           18745 non-null  string
#  13  Domains             10184 non-null  string
# dtypes: Float64(2), Int64(8), string(4)
# memory usage: 2.4 MB

# %% [markdown]
# ### Null Handling
# - First, we'll count nulls per column
# - Next, we'll inspect samples of the dataset where each column has nulls

# %%
# count nulls per column
null_counts = df.isnull().sum().sort_values(ascending=False)

# Filter on columns with nulls
null_counts = null_counts[null_counts > 0]

# Let's turn this series into a dataframe! Why, you ask? She deserves to feel pretty.
display_nulls = (null_counts
    .reset_index(name='Null Count')
    .rename(columns={'index':'Column Name'})
                )

display(Markdown("#### Null count per column with NULLs"))
display(display_nulls)
# Out:
# #### Null count per column with NULLs
# Empty DataFrame
# Columns: [Column Name, Null Count]
# Index: []

# %% [markdown]
# > **Lesson learned from the code below:**
# >
# >
# > The code below worked in my local Jupyter Notebook, but the red highlights vanished on GitHub previews. This was how I learned that GitHub strips out custom CSS for security reasons.
# >
# > I've replaced the display_df code below with a version that allows me to see red cells while developing while also forcing GitHub to explicitly write `NaN`.
# >
# > For future reference, here is the original code that only works locally:
#
# ```python
# # This renders red nulls locally, but completely blank cells on GitHub
# display_df = df[df[col].isnull()].head().style.highlight_null(color='red')
# display(display_df)

# %%
# Inspect samples of the dataset where each column has nulls

def inspect_nulls(df):
    # First, list the columns with nulls
    null_counts = df.isnull().sum()
    cols_with_nulls = null_counts[null_counts > 0].index

    # Add condition for no nulls
    if len(cols_with_nulls) == 0:
        display(Markdown("#### Huzzah! No nulls found!"))
        return

    # Loop for null cols
    for col in cols_with_nulls:
        display(Markdown(f"---\n#### Top 5 rows where `{col}` is NULL"))
        display_df = (
            df[df[col].isnull()]
            .head()
            .style
            .format(na_rep="NaN") 
            .highlight_null(color='red')
        )
        display(display_df)

inspect_nulls(df)
# Out:
# ---
# #### Top 5 rows where `ID` is NULL
# <style type="text/css">
# #T_80922_row0_col0, #T_80922_row0_col11, #T_80922_row0_col12, #T_80922_row0_col13, #T_80922_row1_col0, #T_80922_row1_col11, #T_80922_row1_col12, #T_80922_row1_col13, #T_80922_row2_col0, #T_80922_row2_col11, #T_80922_row2_col12, #T_80922_row2_col13, #T_80922_row3_col0, #T_80922_row3_col11, #T_80922_row3_col12, #T_80922_row3_col13, #T_80922_row4_col0, #T_80922_row4_col11, #T_80922_row4_col12, #T_80922_row4_col13 {
#   background-color: red;
# }
# </style>
# <table id="T_80922">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80922_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_80922_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_80922_level0_col2" class="col_heading level0 col2" >Year Published</th>
#       <th id="T_80922_level0_col3" class="col_heading level0 col3" >Min Players</th>
#       <th id="T_80922_level0_col4" class="col_heading level0 col4" >Max Players</th>
#       <th id="T_80922_level0_col5" class="col_heading level0 col5" >Play Time</th>
#       <th id="T_80922_level0_col6" class="col_heading level0 col6" >Min Age</th>
#       <th id="T_80922_level0_col7" class="col_heading level0 col7" >Users Rated</th>
#       <th id="T_80922_level0_col8" class="col_heading level0 col8" >Rating Average</th>
#       <th id="T_80922_level0_col9" class="col_heading level0 col9" >BGG Rank</th>
#       <th id="T_80922_level0_col10" class="col_heading level0 col10" >Complexity Average</th>
#       <th id="T_80922_level0_col11" class="col_heading level0 col11" >Owned Users</th>
#       <th id="T_80922_level0_col12" class="col_heading level0 col12" >Mechanics</th>
#       <th id="T_80922_level0_col13" class="col_heading level0 col13" >Domains</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_
ains</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9df9_level0_row0" class="row_heading level0 row0" >2828</th>
#       <td id="T_e9df9_row0_col0" class="data row0 col0" >202755</td>
#       <td id="T_e9df9_row0_col1" class="data row0 col1" >Guildhall Fantasy: Fellowship</td>
#       <td id="T_e9df9_row0_col2" class="data row0 col2" >2016</td>
#       <td id="T_e9df9_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_e9df9_row0_col4" class="data row0 col4" >4</td>
#       <td id="T_e9df9_row0_col5" class="data row0 col5" >45</td>
#       <td id="T_e9df9_row0_col6" class="data row0 col6" >10</td>
#       <td id="T_e9df9_row0_col7" class="data row0 col7" >565</td>
#       <td id="T_e9df9_row0_col8" class="data row0 col8" >7.130000</td>
#       <td id="T_e9df9_row0_col9" class="data row0 col9" >2830</td>
#       <td id="T_e9df9_row0_col10" class="data row0 col10" >2.000000</td>
#       <td id="T_e9df9_row0_col11" class="data row0 col11" >NaN</td>
#       <td id="T_e9df9_row0_col12" class="data row0 col12" >Hand Management, Take That, Set Collection</td>
#       <td id="T_e9df9_row0_col13" class="data row0 col13" >NaN</td>
#     </tr>
#     <tr>
#       <th id="T_e9df9_level0_row1" class="row_heading level0 row1" >3590</th>
#       <td id="T_e9df9_row1_col0" class="data row1 col0" >196305</td>
#       <td id="T_e9df9_row1_col1" class="data row1 col1" >Guildhall Fantasy: Alliance</td>
#       <td id="T_e9df9_row1_col2" class="data row1 col2" >2016</td>
#       <td id="T_e9df9_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_e9df9_row1_col4" class="data row1 col4" >4</td>
#       <td id="T_e9df9_row1_col5" class="data row1 col5" >45</td>
#       <td id="T_e9df9_row1_col6" class="data row1 col6" >10</td>
#       <td id="T_e9df9_row1_col7" class="data row1 col7" >360</td>
#       <td id="T_e9df9_row1_col8" class="data row1 col8" >7.200000</td>
#       <td id="T_e9df9_row1_col9" class="data row1 col9" >3592</td>
#       <td id="T_e9df9_row1_col10" class="data row1 col10" >2.140000</td>
#       <td id="T_e9df9_row1_col11" class="data row1 col11" >NaN</td>
#       <td id="T_e9df9_row1_col12" class="data row1 col12" >Hand Management, Set Collection, Take That</td>
#       <td id="T_e9df9_row1_col13" class="data row1 col13" >NaN</td>
#     </tr>
#     <tr>
#       <th id="T_e9df9_level0_row2" class="row_heading level0 row2" >3739</th>
#       <td id="T_e9df9_row2_col0" class="data row2 col0" >196306</td>
#       <td id="T_e9df9_row2_col1" class="data row2 col1" >Guildhall Fantasy: Coalition</td>
#       <td id="T_e9df9_row2_col2" class="data row2 col2" >2016</td>
#       <td id="T_e9df9_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_e9df9_row2_col4" class="data row2 col4" >4</td>
#       <td id="T_e9df9_row2_col5" class="data row2 col5" >45</td>
#       <td id="T_e9df9_row2_col6" class="data row2 col6" >10</td>
#       <td id="T_e9df9_row2_col7" class="data row2 col7" >336</td>
#       <td id="T_e9df9_row2_col8" class="data row2 col8" >7.190000</td>
#       <td id="T_e9df9_row2_col9" class="data row2 col9" >3741</td>
#       <td id="T_e9df9_row2_col10" class="data row2 col10" >2.130000</td>
#       <td id="T_e9df9_row2_col11" class="data row2 col11" >NaN</td>
#       <td id="T_e9df9_row2_col12" class="data row2 col12" >Hand Management, Set Collection, Take That</td>
#       <td id="T_e9df9_row2_col13" class="data row2 col13" >NaN</td>
#     </tr>
#     <tr>
#       <th id="T_e9df9_level0_row3" class="row_heading level0 row3" >5807</th>
#       <td id="T_e9df9_row3_col0" class="data row3 col0" >289</td>
#       <td id="T_e9df9_row3_col1" class="data row3 col1" >Chariot Lords</td>
#       <td id="T_e9df9_row3_col2" class="data row3 col2" >1999</td>
#       <td id="T_e9df9_row3_col3" class="data row3 col3" >3</td>
#       <td id="T_e9df9_row3_col4" class="data row3 col4" >4</td>
#       <td id="T_e9df9_row3_col5" class="data row3 col5" >360</td>
#       <td id="T_e9df9_row3_col6" class="data row3 col6" >12</td>
#       <td id="T_e9df9_row3_col7" class="data row3 col7" >221</td>
#       <td id="T_e9df9_row3_col8" class="data row3 col8" >6.680000</td>
#       <td id="T_e9df9_row3_col9" class="data row3 col9" >5809</td>
#       <td id="T_e9df9_row3_col10" class="data row3 col10" >3.000000</td>
#       <td id="T_e9df9_row3_col11" class="data row3 col11" >NaN</td>
#       <td id="T_e9df9_row3_col12" class="data row3 col12" >Area Movement, Variable Player Powers</td>
#       <td id="T_e9df9_row3_col13" class="data row3 col13" >NaN</td>
#     </tr>
#     <tr>
#       <th id="T_e9df9_level0_row4" class="row_heading level0 row4" >9202</th>
#       <td id="T_e9df9_row4_col0" class="data row4 col0" >6813</td>
#       <td id="T_e9df9_row4_col1" class="data row4 col1" >Operation Market Garden: Descent into Hell </td>
#       <td id="T_e9df9_row4_col2" class="data row4 col2" >1985</td>
#       <td id="T_e9df9_row4_col3" class="data row4 col3" >2</td>
#       <td id="T_e9df9_row4_col4" class="data row4 col4" >2</td>
#       <td id="T_e9df9_row4_col5" class="data row4 col5" >120</td>
#       <td id="T_e9df9_row4_col6" class="data row4 col6" >12</td>
#       <td id="T_e9df9_row4_col7" class="data row4 col7" >94</td>
#       <td id="T_e9df9_row4_col8" class="data row4 col8" >6.720000</td>
#       <td id="T_e9df9_row4_col9" class="data row4 col9" >9204</td>
#       <td id="T_e9df9_row4_col10" class="data row4 col10" >3.000000</td>
#       <td id="T_e9df9_row4_col11" class="data row4 col11" >NaN</td>
#       <td id="T_e9df9_row4_col12" class="data row4 col12" >Dice Rolling, Events, Grid Movement, Hexagon Grid, Hidden Movement, Movement Points, Ratio / Combat Results Table, Secret Unit Deployment, Simulation, Zone of Control</td>
#       <td id="T_e9df9_row4_col13" class="data row4 col13" >NaN</td>
#     </tr>
#   </tbody>
# </table>
# ---
# #### Top 5 rows where `Mechanics` is NULL
# <style type="text/css">
# #T_e6bc5_row0_col12, #T_e6bc5_row1_col12, #T_e6bc5_row2_col12, #T_e6bc5_row3_col12, #T_e6bc5_row4_col12 {
#   background-color: red;
# }
# </style>
# <table id="T_e6bc5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6bc5_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_e6bc5_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_e6bc5_level0_col2" class="col_heading level0 col2" >Year Published</th>
#       <th id="T_e6bc5_level0_col3" class="col_heading level0 col3" >Min Players</th>
#       <th id="T_e6bc5_level0_col4" class="col_heading level0 col4" >Max Players</th>
#       <th id="T_e6bc5_level0_col5" class="col_heading level0 col5" >Play Time</th>
#       <th id="T_e6bc5_level0_col6" class="col_heading level0 col6" >Min Age</th>
#       <th id="T_e6bc5_level0_col7" class="col_heading level0 col7" >Users Rated</th>
#       <th id="T_e6bc5_level0_col8" class="col_heading level0 col8" >Rating Average</th>
#       <th id="T_e6bc5_level0_col9" class="col_heading level0 col9" >BGG Rank</th>
#       <th id="T_e6bc5_level0_col10" class="col_heading level0 col10" >Complexity Average</th>
#       <th id="T_e6bc5_level0_col11" class="col_heading level0 col11" >Owned Users</th>
#       <th id="T_e6bc5_level0_col12" class="col_heading level0 col12" >Mechanics</th>
#       <th id="T_e6bc5_level0_col13" class="col_heading level0 col13" >Domains</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6bc5_level0_row0" class="row_heading level0 row0" >1059</th>
#       <td id="T_e6bc5_row0_col0" class="data row0 col0" >85256</td>
#       <td id="T_e6bc5_row0_col1" class="data row0 col1" >Timeline: Inventions</td>
#       <td id="T_e6bc5_row0_col2" class="data row0 col2" >2010</td>
#       <td id="T_e6bc5_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_e6bc5_row0_col4" class="data row0 col4" >8</td>
#       <td id="T_e6bc5_row0_col5" class="data row0 col5" >15</td>
#       <td id="T_e6bc5_row0_col6" class="data row0 col6" >8</td>
#       <td id="T_e6bc5_row0_col7" class="data row0 col7" >7257</td>
#       <td id="T_e6bc5_row0_col8" class="data row0 col8" >6.710000</td>
#       <td id="T_e6bc5_row0_col9" class="data row0 col9" >1060</td>
#       <td id="T_e6bc5_row0_col10" class="data row0 col10" >1.110000</td>
#       <td id="T_e6bc5_row0_col11" class="data row0 col11" >12448</td>
#       <td id="T_e6bc5_row3_col13" class="data row3 col13" >Family Games</td>
#     </tr>
#     <tr>
#       <th id="T_e6bc5_level0_row4" class="row_heading level0 row4" >1397</th>
#       <td id="T_e6bc5_row4_col0" class="data row4 col0" >145189</td>
#       <td id="T_e6bc5_row4_col1" class="data row4 col1" >Timeline: Music & Cinema</td>
#       <td id="T_e6bc5_row4_col2" class="data row4 col2" >2013</td>
#       <td id="T_e6bc5_row4_col3" class="data row4 col3" >2</td>
#       <td id="T_e6bc5_row4_col4" class="data row4 col4" >8</td>
#       <td id="T_e6bc5_row4_col5" class="data row4 col5" >15</td>
#       <td id="T_e6bc5_row4_col6" class="data row4 col6" >8</td>
#       <td id="T_e6bc5_row4_col7" class="data row4 col7" >3090</td>
#       <td id="T_e6bc5_row4_col8" class="data row4 col8" >6.750000</td>
#       <td id="T_e6bc5_row4_col9" class="data row4 col9" >1398</td>
#       <td id="T_e6bc5_row4_col10" class="data row4 col10" >1.100000</td>
#       <td id="T_e6bc5_row4_col11" class="data row4 col11" >5986</td>
#       <td id="T_e6bc5_row4_col12" class="data row4 col12" >NaN</td>
#       <td id="T_e6bc5_row4_col13" class="data row4 col13" >Family Games, Party Games</td>
#     </tr>
#   </tbody>
# </table>
# ---
# #### Top 5 rows where `Domains` is NULL
# <style type="text/css">
# #T_13f99_row0_col13, #T_13f99_row1_col13, #T_13f99_row2_col13, #T_13f99_row3_col13, #T_13f99_row4_col13 {
#   background-color: red;
# }
# </style>
# <table id="T_13f99">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13f99_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_13f99_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_13f99_level0_col2" class="col_heading level0 col2" >Year Published</th>
#       <th id="T_13f99_level0_col3" class="col_heading level0 col3" >Min Players</th>
#       <th id="T_13f99_level0_col4" class="col_heading level0 col4" >Max Players</th>
#       <th id="T_13f99_level0_col5" class="col_heading level0 col5" >Play Time</th>
#       <th id="T_13f99_level0_col6" class="col_heading level0 col6" >Min Age</th>
#       <th id="T_13f99_level0_col7" class="col_heading level0 col7" >Users Rated</th>
#       <th id="T_13f99_level0_col8" class="col_heading level0 col8" >Rating Average</th>
#       <th id="T_13f99_level0_col9" class="col_heading level0 col9" >BGG Rank</th>
#       <th id="T_13f99_level0_col10" class="col_heading level0 col10" >Complexity Average</th>
#       <th id="T_13f99_level0_col11" class="col_heading level0 col11" >Owned Users</th>
#       <th id="T_13f99_level0_col12" class="col_heading level0 col12" >Mechanics</th>
#       <th id="T_13f99_level0_col13" class="col_heading level0 col13" >Domains</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13f99_level0_row0" class="row_heading level0 row0" >663</th>
#       <td id="T_13f99_row0_col0" class="data row0 col0" >293141</td>
#       <td id="T_13f99_row0_col1" class="data row0 col1" >King of Tokyo: Dark Edition</td>
#       <td id="T_13f99_row0_col2" class="data row0 col2" >2020</td>
#       <td id="T_13f99_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_13f99_row0_col4" class="data row0 col4" >6</td>
#       <td id="T_13f99_row0_col5" class="data row0 col5" >30</td>
#       <td id="T_13f99_row0_col6" class="data row0 col6" >8</td>
#       <td id="T_13f99_row0_col7" class="data row0 col7" >1854</td>
#       <td id="T_13f99_row0_col8" class="data row0 col8" >7.890000</td>
#       <td id="T_13f99_row0_col9" class="data row0 col9" >664</td>
#       <td id="T_13f99_row0_col10" class="data row0 col10" >1.630000</td>
#       <td id="T_13f99_row0_col11" class="data row0 col11" >5157</td>
#       <td id="T_13f99_row0_col12" class="data row0 col12" >Card Drafting, Dice Rolling, King of the Hill, Player Elimination, Push Your Luck</td>
#       <td id="T_13f99_row0_col13" class="data row0 col13" >NaN</td>
#     </tr>
#     <tr>
#       <th id="T_13f99_level0_row1" class="row_heading level0 row1" >1011</th>
#       <td id="T_13f99_row1_col0" class="data row1 col0" >177802</td>
#       <td id="T_13f99_row1_col1" class="data row1 col1" >Smash Up: It's Your Fault!</td>
#       <td id="T_13f99_row1_col2" class="data row1 col2" >2016</td>
#       <td id="T_13f99_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_13f99_row1_col4" class="data row1 col4" >2</td>
#       <td id="T
aN</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Conclusions**
#
# Based on the samples above:
# - nulls tend to come in groups for `ID`, `Year Published`, and `Owned Users`
# - `Mechanics` and `Domains` are more often the only null value in a row

# %% [markdown]
# Based on the samples and counts, this is my conclusion for each column with missing values:
# | Column Name | Null Count | Strategy |
# | :--- | :--- | :--- |
# | **Domains** | 10,159 | Fill with Null Indicator |
# | **Mechanics** | 1,598 | Fill with Null Indicator |
# | **Owned Users** | 23 | Drop Rows |
# | **ID** | 16 | Drop Rows |
# | **Year Published** | 1 | Drop Rows |
#
# `Domains` and `Mechanics` have a lot of nulls. It could be random or the games with nulls could have more in common. Either way, let's track it by keeping these rows and imputing with something else.

# %% [markdown]
# Next, I'll explore `Domains` and `Mechanics` to understand them better before deciding on impute values and next steps

# %%
# Let's see how many unique values exist for Domains and Mechanis
check_unique = ['Domains', 'Mechanics']

for col in check_unique:
    print(f"{col}: {df[col].nunique()} unique values")
# Out:
# Domains: 39 unique values
# Mechanics: 7381 unique values

# %% [markdown]
# Since `Domains` has a limited # of unique values, let's check them all out.
# - Conclusion: It's a mix of single value and comma delimited lists

# %%
display(Markdown("#### Value counts for `Domains`"))
display(df['Domains'].value_counts(dropna=False).reset_index())
# Out:
# #### Value counts for `Domains`
#                                            Domains  count
# 0                                             <NA>  10159
# 1                                         Wargames   3029
# 2                                   Strategy Games   1455
# 3                                     Family Games   1340
# 4                                   Abstract Games    869
# 5                                 Children's Games    708
# 6                                   Thematic Games    647
# 7                                      Party Games    409
# 8                     Family Games, Strategy Games    354
# 9                               Customizable Games    235
# 10                  Strategy Games, Thematic Games    217
# 11                       Family Games, Party Games    139
# 12                        Thematic Games, Wargames    139
# 13                    Abstract Games, Family Games    116
# 14                    Family Games, Thematic Games    109
# 15                  Children's Games, Family Games    105
# 16                        Strategy Games, Wargames     99
# 17                  Abstract Games, Strategy Games     40
# 18                     Party Games, Thematic Games     36
# 19              Customizable Games, Strategy Games     26
# 20                Abstract Games, Children's Games     23
# 21                    Customizable Games, Wargames     18
# 22              Customizable Games, Thematic Games     15
# 23                        Abstract Games, Wargames     13
# 24                     Party Games, Strategy Games      7
# 25                   Children's Games, Party Games      6
# 26        Strategy Games, Thematic Games, Wargames      5
# 27                          Family Games, Wargames      5
# 28                     Abstract Games, Party Games      4
# 29                      Children's Games, Wargames      4
# 30              Abstract Games, Customizable Games      2
# 31     Children's Games, Family Games, Party Games      2
# 32  Abstract Games, Strategy Games, Thematic Games      1
# 33      Abstract Games, Children's Games, Wargames      1
# 34    Customizable Games, Thematic Games, Wargames      1
# 35    Family Games, Strategy Games, Thematic Games      1
# 36                           Party Games, Wargames      1
# 37          Family Games, Thematic Games, Wargames      1
# 38       Family Games, Party Games, Thematic Games      1
# 39                  Abstract Games, Thematic Games      1

# %% [markdown]
# Since there are many unique values for `Mechanics`, let's look at the top and bottom values
# - Conclusion: There are more lists, separated by a "," or a "/"

# %%
# The Top 10
display(Markdown("#### Top 10 most common values for `Mechanics`"))
display(df['Mechanics'].value_counts(dropna=False).head(10).reset_index())

# The Bottom 10
display(Markdown("#### Bottom 10 most common values for `Mechanics`"))
display(df['Mechanics'].value_counts(dropna=False).tail(10).reset_index())
# Out:
# #### Top 10 most common values for `Mechanics`
#                                 Mechanics  count
# 0                                    <NA>   1598
# 1                         Hand Management    432
# 2                            Hexagon Grid    412
# 3                            Dice Rolling    372
# 4                    Roll / Spin and Move    369
# 5                          Tile Placement    285
# 6  Dice Rolling, Hexagon Grid, Simulation    260
# 7              Dice Rolling, Hexagon Grid    256
# 8                          Set Collection    231
# 9         Hand Management, Set Collection    179
# #### Bottom 10 most common values for `Mechanics`
#                                            Mechanics  count
# 0  Area Majority / Influence, Card Drafting, Modu...      1
# 1  Area Majority / Influence, Campaign / Battle C...      1
# 2  Area Movement, Dice Rolling, Events, Race, Sce...      1
# 3  Area Majority / Influence, Dice Rolling, Push ...      1
# 4       Action Queue, Modular Board, Team-Based Game      1
# 5  Dice Rolling, Measurement Movement, Pick-up an...      1
# 6  Action Points, Dice Rolling, Grid Movement, Mo...      1
# 7  Area Movement, Hidden Movement, Secret Unit De...      1
# 8  Auction/Bidding, Auction: Sealed Bid, Constrai...      1
# 9  Dice Rolling, Grid Movement, Race, Roll / Spin...      1

# %% [markdown]
# **Conclusions**
#
# Based on the investigation above, I'll simply fill nulls with 'Unknown' and then proceed with one-hot encoding later

# %%
# Drop rows based on nulls
drop_nulls = ['Owned Users', 'ID', 'Year Published']
df = df.dropna(subset = drop_nulls)

# Impute
df['Domains'] = df['Domains'].fillna("Unknown")
df['Mechanics'] = df['Mechanics'].fillna("Unknown")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20320 entries, 0 to 20342
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  20320 non-null  string
#  1   Name                20320 non-null  string
#  2   Year Published      20320 non-null  Int64
#  3   Min Players         20320 non-null  Int64
#  4   Max Players         20320 non-null  Int64
#  5   Play Time           20320 non-null  Int64
#  6   Min Age             20320 non-null  Int64
#  7   Users Rated         20320 non-null  Int64
#  8   Rating Average      20320 non-null  Float64
#  9   BGG Rank            20320 non-null  Int64
#  10  Complexity Average  20320 non-null  Float64
#  11  Owned Users         20320 non-null  Int64
#  12  Mechanics           20320 non-null  string
#  13  Domains             20320 non-null  string
# dtypes: Float64(2), Int64(8), string(4)
# memory usage: 2.5 MB

# %%
df.head()
# Out:
#        ID                               Name  Year Published  Min Players  \
# 0  174430                         Gloomhaven            2017            1
# 1  161936          Pandemic Legacy: Season 1            2015            2
# 2  224517                  Brass: Birmingham            2018            2
# 3  167791                  Terraforming Mars            2016            1
# 4  233078  Twilight Imperium: Fourth Edition            2017            3
#
#    Max Players  Play Time  Min Age  Users Rated  Rating Average  BGG Rank  \
# 0            4        120       14        42055            8.79         1
# 1            4         60       13        41643            8.61         2
# 2            4        120       14        19217            8.66         3
# 3            5        120       12        64864            8.43         4
# 4            6        480       14        13468             8.7         5
#
#    Complexity Average  Owned Users  \
# 0                3.86        68323
# 1                2.84        65294
# 2                3.91        28785
# 3                3.24        87099
# 4                4.22        16831
#
#                                            Mechanics  \
# 0  Action Queue, Action Retrieval, Campaign / Bat...
# 1  Action Points, Cooperative Game, Hand Manageme...
# 2  Hand Management, Income, Loans, Market, Networ...
# 3  Card Drafting, Drafting, End Game Bonuses, Han...
# 4  Action Drafting, Area Majority / Influence, Ar...
#
#                           Domains
# 0  Strategy Games, Thematic Games
# 1  Strategy Games, Thematic Games
# 2                  Strategy Games
# 3                  Strategy Games
# 4  Strategy Games, Thematic Games

# %% [markdown]
# ### Checking for Duplicates
# - We'll use .duplicated() to check for `ID` duplicates (since it's the primary key) and row duplicates
# - **Conclusion:** No dups!

# %%
df[df.duplicated(subset=['ID'])]
# Out:
# Empty DataFrame
# Columns: [ID, Name, Year Published, Min Players, Max Players, Play Time, Min Age, Users Rated, Rating Average, BGG Rank, Complexity Average, Owned Users, Mechanics, Domains]
# Index: []

# %%
df[df.duplicated()] # No rows are entirely the same
# Out:
# Empty DataFrame
# Columns: [ID, Name, Year Published, Min Players, Max Players, Play Time, Min Age, Users Rated, Rating Average, BGG Rank, Complexity Average, Owned Users, Mechanics, Domains]
# Index: []

# %%
# Now let's pull only the rows where Count ID > 1

id_count_df = df.groupby('ID', as_index = False).agg(
    RowCnt = ('ID', 'count')
)

#id_count_df[id_count_df['RowCnt'] > 1]
id_count_df.head()
# Out:
#        ID  RowCnt
# 0       1       1
# 1      10       1
# 2    1000       1
# 3  100015       1
# 4   10008       1

# %%
# This creates a boolean mask where the count of that row's ID is > 1
df_duplicates = df[df.groupby('ID')['ID'].transform('count') > 1]

# Sort by ID so you can easily compare the duplicates side-by-side
df_duplicates.sort_values('ID')
# Out:
# Empty DataFrame
# Columns: [ID, Name, Year Published, Min Players, Max Players, Play Time, Min Age, Users Rated, Rating Average, BGG Rank, Complexity Average, Owned Users, Mechanics, Domains]
# Index: []

# %% [markdown]
# # TODO:
# - Replace "/" with commas
# - Start data exploration
# - Learn about the stuff below and make my own version
# - Combine more

# %% [markdown]
# It is a bit of a "lightbulb moment" when you move from looking at a single column to looking at a **Corpus**. You stop seeing the data as just "text in a box" and start seeing it as a **frequency of ideas.**
#
# Here are the highlights of why these two tools are the "secret sauce" for projects involving tags, categories, or lists.
#
# ---
#
# ### 1. What is a Corpus? (The "Master Bag")
#
# In Data Science, a **Corpus** is simply a collection of all the text data you are analyzing.
#
# * **The Highlight:** It breaks the "row" boundary.
# * **In your case:** Instead of saying *"This game has (Dice Rolling, Hand Management),"* the corpus says *"I have seen the word 'Dice Rolling' 5,000 times and 'Hand Management' 4,000 times across my entire universe of games."*
# * **Why it matters:** It allows you to perform **Global Analysis**. You can't find the "most popular mechanic" by looking at individual rows; you have to look at the corpus.
#
# ### 2. What is `collections.Counter`? (The "High-Speed Calculator")
#
# `Counter` is a specialized dictionary in Python designed specifically for—you guessed it—counting.
#
# * **The Highlight:** It is significantly faster and more "Pythonic" than writing `if item not in dict: dict[item] = 1`.
# * **The "Killer Feature":** The `.most_common(n)` method. With one line of code, it can tell you the top 10 mechanics, instantly sorted by frequency.
# * **In your case:** It handles the heavy lifting of turning that giant list of 100,000+ items into a tidy summary of unique tags and their totals.
#
# ---
#
# ### 3. Why they are vital for BoardGameGeek Data
#
# Multi-label data (columns with commas) is notoriously difficult to analyze. Here is how the Corpus + Counter combo solves your specific problems:
#
# #### A. Finding "Dead Weight" (Pruning)
#
# By using `Counter`, you might discover that 300 out of your 500 mechanics only appear in **one** game.
#
# > **Decision:** You shouldn't make 300 columns for those. The Corpus tells you exactly which mechanics are "noise" and which are "signal."
#
# #### B. Spotting "Hidden" Overlaps
#
# Sometimes games use different terms for the same thing. By looking at the unique items in your Corpus, you might see:
#
# * `Solo Game`
# * `Single Player`
# * `Solitaire`
# By identifying these in the Corpus, you can **standardize** them (replace all with one term) before you do your one-hot encoding.
#
# #### C. Calculating "Market Share"
#
# As we did in your chart, the Corpus allows you to see the "density" of a mechanic. If "Dice Rolling" is in 27% of games, that’s a massive trend. Without a Corpus, calculating that percentage is much more complex.
#
# ---
#
# ### Summary of the Power-Up
#
# | Tool | What it does | Your Project Benefit |
# | --- | --- | --- |
# | **Corpus** | Flattening | Turns "Dice, Cards" (Row 1) and "Dice, Board" (Row 2) into one list: `[Dice, Cards, Dice, Board]`. |
# | **Counter** | Aggregating | Tells you `Dice: 2, Cards: 1, Board: 1`. |
# | **Analysis** | Ranking | Tells you "Dice" is your most important feature for predicting ratings. |
#
# ---
#
# ### A Final "Pro" Tip
#
# Now that you have your `Mechanics_corpus` and your `Counter`, you can actually use them to **filter** your original dataframe. For example, you can now easily answer: *"Show me all games that have any of the Top 5 most popular mechanics."*
#
# **Would you like me to show you how to use your `Counter` to automatically create a "Simplified Mechanics" column that only includes the Top 10 tags?**

# %%
# Test code
import re
data = df.copy()
#Defining a function to clean up the text 
def Clean(Text):
    sms = re.sub('[^a-zA-Z], ,', ' ', str(Text)) 
    sms = sms.replace("/",",")
    sms = sms.split()
    sms = ' '.join(sms)
    return sms
data["Mechanics"] = data["Mechanics"].apply(Clean)
data["Domains"] = data["Domains"].apply(Clean)

print("First three values of Mechanics after cleaning text:")
print(data["Mechanics"][:3], "\n")

print("First three values of Domains after cleaning text:")
print(data["Domains"][:3])

# %%
#Code to get Corpus
def Get_Corpus(bla):
    corpus= []
    for i in bla:
        item = i.split(",")
        corpus += item
    return corpus
#Code to delete extra space
def space_eleminator(list):
    vals=[]
    for i in list:
        m = i.lstrip()
        vals.append(m)
    return vals

Mechanics_corpus = space_eleminator(Get_Corpus(data["Mechanics"]))
Domains_corpus = space_eleminator(Get_Corpus(data["Domains"]))
print("First 5 tokens in the Mechanics features:\n", Mechanics_corpus[:5])
print("First 5 tokens in the Domains features:\n", Domains_corpus[:5], "\n")

# %%
from collections import Counter
#Creating a count dictionary for items in Mechanics 
Mechs_dic = Counter(Mechanics_corpus)
#Exploring the The occurence of Mechanincs 
Item_M = list(Mechs_dic.keys())
Freq_M = list(Mechs_dic.values())

print("Number of unique items in Machanics:", len(Mechs_dic))
print("Most frequently used Mechanics appeared:", max(Freq_M), "times")
print("Least frequently used Mechanics appeared:", min(Freq_M), "time")

# %%
from collections import Counter

# Count occurrences in your corpus
counts = Counter(Mechanics_corpus)

# Convert to a DataFrame for easy plotting
trend_df = pd.DataFrame(counts.items(), columns=['Mechanic', 'Count']).sort_values(by='Count', ascending=False)

# Calculate percentage (to see how 'sparse' the column will be)
trend_df['Percent_of_Games'] = (trend_df['Count'] / len(data)) * 100

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.barplot(data=trend_df.head(20), x='Count', y='Mechanic', palette='viridis')

plt.title('Top 20 Board Game Mechanics', fontsize=15)
plt.xlabel('Number of Games')
plt.ylabel('Mechanic Name')
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.barplot(data=trend_df.tail(20), x='Count', y='Mechanic', palette='viridis')

plt.title('Bottom 20 Board Game Mechanics', fontsize=15)
plt.xlabel('Number of Games')
plt.ylabel('Mechanic Name')
plt.show()

# %%
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Calculate Frequency and Percentage
counts = Counter(Mechanics_corpus)
total_games = len(df) # or 'data' depending on your variable name

trend_df = pd.DataFrame(counts.items(), columns=['Mechanic', 'Count'])
trend_df = trend_df.sort_values(by='Count', ascending=False).reset_index(drop=True)

# Calculate Percentage
trend_df['Percentage (%)'] = (trend_df['Count'] / total_games) * 100

# 2. Create the Visualization
plt.figure(figsize=(12, 10))
ax = sns.barplot(
    data=trend_df.head(20), 
    x='Count', 
    y='Mechanic', 
    palette='magma'
)

# 3. Add Annotations (The # and % labels)
for i, p in enumerate(ax.patches):
    count = int(p.get_width())
    pct = trend_df.loc[i, 'Percentage (%)']
    
    # Create a string label: "Count (Pct%)"
    label = f"{count:,} ({pct:.1f}%)"
    
    # Place the text at the end of the bar
    ax.annotate(label, 
                (p.get_width(), p.get_y() + p.get_height() / 2), 
                ha='left', va='center', 
                fontsize=10, color='black', xytext=(5, 0), 
                textcoords='offset points')

plt.title('Top 20 Mechanics: Frequency and Market Share', fontsize=16, pad=20)
plt.xlabel('Number of Games (#)', fontsize=12)
plt.ylabel('Mechanic Name', fontsize=12)
plt.xlim(0, trend_df['Count'].max() * 1.15) # Add space for labels
sns.despine()
plt.tight_layout()
plt.show()

# 4. Display as a Clean Table
print(f"{' TOP 10 MECHANICS ANALYSIS ':=^50}")
print(trend_df.head(10).to_string(index=False, formatters={'Percentage (%)': '{:,.2f}%'.format}))

# %%
# looking for opportunities to combine
from difflib import get_close_matches

# Pick a mechanic and see what looks similar in your corpus
test_item = "Auction: English"
matches = get_close_matches(test_item, counts.keys(), cutoff=0.6)
print(f"Items similar to '{test_item}': {matches}")

# %%
# Get the first word of every mechanic and count them
root_counts = Counter([m.split(':')[0].strip() for m in Mechanics_corpus])

# Show the most common 'Root' mechanics
print(root_counts.most_common(30))

# %%
# Define your mapping. cleaner than if/else
mapping = {
    'Auction: English': 'Auction',
    'Auction: Dexterity': 'Auction',
    'Auction: Dutch': 'Auction',
    'Impulse Movement': 'Movement',
    'Pattern Movement': 'Movement'
}

# Apply it to your corpus or dataframe
# .get(x, x) means "replace if in dictionary, otherwise keep original"
data['Mechanics_Clean'] = data['Mechanics_List'].apply(lambda x: [mapping.get(item, item) for item in x])

# %%
# 1. Get unique mechanics from your Counter
unique_mechanics = list(counts.keys())

# 2. Identify mechanics with colons
colon_mechanics = [m for m in unique_mechanics if ":" in m]

# 3. Create a suggestion map
# Logic: "Auction: English" -> Key: "Auction", Value: ["Auction: English", "Auction: Dutch"...]
suggestions = {}
for m in colon_mechanics:
    parent = m.split(":")[0].strip()
    if parent not in suggestions:
        suggestions[parent] = []
    suggestions[parent].append(m)

# 4. Print the Report
print(f"\n{' COLON-GROUPING SUGGESTIONS ':=^60}\n")
print(f"{'Parent Category':<25} | {'Sub-types Found':<10} | {'Total Count':<10}")
print("-" * 60)

for parent, subs in sorted(suggestions.items(), key=lambda x: len(x[1]), reverse=True):
    # Calculate the total weight of this group
    total_group_count = sum(counts[s] for s in subs)
    
    if len(subs) > 1: # Only show groups with more than one sub-type
        print(f"{parent:<25} | {len(subs):^15} | {total_group_count:,}")

print(f"\n{'='*60}")
